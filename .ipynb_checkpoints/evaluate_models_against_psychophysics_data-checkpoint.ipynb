# %% [markdown]
# # Notebook to perform all evaluations of models against human psychophysical data, and generate all data analysis plots in paper
# ---

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ## Pilot experiment

# %% [markdown]
# ### Supplementary Figure 1b: pilot experiment testing of models with different latent dimensionality

# %% [markdown]
# ## Experiment 1 (gloss ratings for random novel images)

# %% [markdown]
# ### Figure 4a (left panel): Experiment 1 data vs PixelVAE model predictions scatterplot

# %% [markdown]
# ### Figure 4a (right panel): Experiment 1 data vs all model predictions summary barplot

# %% [markdown]
# ## Experiment 2 (gloss-modulated images generated by PixelVAE models)

# %% [markdown]
# ### Figure 4b: Experiment 2 data vs PixelVAE model predictions line graph

# %% [markdown]
# ## Experiment 3 (patterns of gloss-constancy along continuous sequences of images varying in shape)

# %% [markdown]
# ### Figure 5b / Supplementary Figure 2: Experiment 3 per-sequence data vs selected model predictions line graphs

# %% [markdown]
# ### Figure 5c: Experiment 3 data vs all model predictions summary barplot

# %% [markdown]
# ## Experiment 4 (degrees of gloss-constancy within pairs of images varying shape and lighting)

# %% [markdown]
# ### Figure 5e: Experiment 4 data vs PixelVAE model predictions scatterplot

# %% [markdown]
# ## Summaries over all experiments
# Notes:
# 1. These exclude Experiment 2, which used images generated by PixelVAE networks, for which there is no ground-truth gloss, so not all models make meaningful predictions.
# 2. Some of these include additional models not shown so far, specifically the variants of PixelVAE networks trained on two alternative training datasets (continuously-varying gloss, and higher-variance shape and lighting, respectively).

# %% [markdown]
# ### Figure 6a: Summary scatterplot of model performance vs ground-truth gloss classification accuracy

# %% [markdown]
# ### Figure 6b: Summary scatterplot of model performance vs model dimensionality

# %% [markdown]
# ### Figure 7b: Representational similarity analysis of gloss prediction patterns across all models

# %% [markdown]
# ### Figure 7c: Barplot of performance for PixelVAE variants

# %% [markdown]
# ## Hyperparameter search

# %% [markdown]
# ### Supplementary Figure 5: Summary of PixelVAE and Resnet models with different architectural and training hyperparameters
